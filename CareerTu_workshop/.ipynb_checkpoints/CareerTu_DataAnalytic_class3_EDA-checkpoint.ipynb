# %%
setwd("~/R/Rdata")

# %%
box_office <- read.csv("box_office.csv", stringsAsFactors = FALSE)

# %%
head(box_office)
# Out:
#   budget   country director          genre  gross     name
# 1 2.37e+08 UK      James Cameron     Action 760507625 Avatar (2009)
# 2 2.00e+08 USA     James Cameron     Drama  658672302 Titanic (1997)
# 3 1.50e+08 USA     Colin Trevorrow   Action 652270625 Jurassic World (2015)
# 4 2.20e+08 USA     Joss Whedon       Action 623357910 The Avengers (2012)
# 5 1.85e+08 USA     Christopher Nolan Action 534858444 The Dark Knight (2008)
# 6 2.00e+08 USA     Gareth Edwards    Action 532177324 Rogue One (2016)
#   rating runtime score star              studio
# 1 PG-13  162     7.8   Sam Worthington   Twentieth Century Fox Film Corporation
# 2 PG-13  194     7.8   Leonardo DiCaprio Twentieth Century Fox Film Corporation
# 3 PG-13  124     7.0   Chris Pratt       Universal Pictures
# 4 PG-13  143     8.1   Robert Downey Jr. Marvel Studios
# 5 PG-13  152     9.0   Christian Bale    Warner Bros.
# 6 PG-13  133     7.9   Felicity Jones    Lucasfilm
#   votes
# 1  958400
# 2  865551
# 3  470625
# ...

# %%
#We'll start by "getting to know" the dataset. 
#The goal is to understand the dataset at a qualitative level, note anything that should be cleaned up, and spot opportunities for feature engineering.
#First, we look at some examples observations to get a "feel" for the dataset. What do we learn?

# %%
#disabling scientific notation in R
options(scipen = 999)

# %%
#install.packages("ggplot2")
library(ggplot2)
ggplot(box_office, aes(x = budget)) + 
  theme_bw() +
  geom_histogram() +
  labs(y = "movie count",
       x="budget ",
       title = "Movie Budget Distribution")
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %%
summary(box_office)
# Out:
#      budget            country            director            genre
#  Min.   :        0   Length:6000        Length:6000        Length:6000
#  1st Qu.:        0   Class :character   Class :character   Class :character
#  Median : 11000000   Mode  :character   Mode  :character   Mode  :character
#  Mean   : 24699184
#  3rd Qu.: 32625000
#  Max.   :300000000
#      gross               name              rating             runtime
#  Min.   :      441   Length:6000        Length:6000        Min.   : 50.0
#  1st Qu.:  1527796   Class :character   Class :character   1st Qu.: 95.0
#  Median : 12298970   Mode  :character   Mode  :character   Median :102.0
#  Mean   : 33416353                                         Mean   :106.6
#  3rd Qu.: 40072560                                         3rd Qu.:115.0
#  Max.   :760507625                                         Max.   :366.0
#      score           star              studio              votes
# ...

# %%
#Based on the summary statistics, we see that some films have a budget of 0 in the dataset. Here are a few examples:

# %%
library(dplyr)
head(box_office %>% filter (budget == 0))
# Out:
#   budget country director         genre     gross
# 1 0      UK      David Yates      Adventure 295983305
# 2 0      USA     Walt Becker      Action    168273550
# 3 0      USA     John G. Avildsen Action    115103979
# 4 0      USA     Nora Ephron      Comedy     95318203
# 5 0      USA     Tyler Perry      Comedy     90485233
# 6 0      USA     Charles Shyer    Comedy     89325780
#   name                                                rating runtime score
# 1 Harry Potter and the Deathly Hallows: Part 1 (2010) PG-13  146     7.7
# 2 Wild Hogs (2007)                                    PG-13  100     5.9
# 3 The Karate Kid Part II (1986)                       PG     113     5.9
# 4 Michael (1996)                                      PG     105     5.7
# 5 Madea Goes to Jail (2009)                           PG-13  103     4.3
# 6 Father of the Bride (1991)                          PG     105     6.5
#   star             studio                        votes
# ...

# %%
#A Harry Potter film with 0 budget? No way. These are most likely missing values / data collection errors. 
#But since our exercise is to investigate profitability of films, we cannot study films with missing budget values.

# %%
# Remove films with "0" budget
box_office <- box_office %>% filter (budget> 0)

# %%
summary(box_office$budget)
# Out:
#      Min.   1st Qu.    Median      Mean   3rd Qu.      Max.
#      6000  10000000  23000000  36242383  47000000 300000000
